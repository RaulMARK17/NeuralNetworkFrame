# %%
#importamos las librerias que se usaran
import numpy as np
import NNframework as NN # nombre del archivo y nombre con el que se accederá a ello

# %%
nn = NN.NeuralNetwork() #se crea el objeto, si se introduce un parametro puede hacerse AUTOMATICMENTE

# %%
nn.createNetwork([5, 10, 15, 20, 2], ['relu', 'relu', 'relu', 'relu']) 
#Se introducen los arreglos con el tamaño de la capa de entrada, el tamaño de las capas ocultas y el tamaño de la capa de salida. También un arreglo con las funciones de activación, para cada capa, excepto la de entrada que no tiene.
# Out:
# Objeto creado.
# Red creada

# %%
nn.visualNN()

# %%
nn.predict([1,.9, .8, .7, .6]) #para hacer una prediccion con la red, se debe introducir un arreglo del mismo tamaño que la entrda, en este caso 5.
# Out:
# array([[496.79923892, 711.61106967]])

# %%
nn.train(x, y, 0.5, decay=0.01, epochs=2000) #esto no funcionará porque no tengo un dataset para el entrenamiento
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3ef1d3569703> in <module>
# ----> 1 nn.train(x, y, 0.5, decay=0.01, epochs=2000)
#
# NameError: name 'x' is not defined

# %%
nn.print(l=True) #dependiendo del identificador puede imprimir los pesos y umbrales en diferentes formatos, a conticuación, codigo python:
# Out:
# # -------------- W --------------
#
# ...

# %%
nn.print() # Formato texto.
# Out:
# # -------------- W --------------
#
# W1
# [[0.36110398 0.55067572 0.16914239 0.21165812 0.56239215 0.9719855
#   0.76501002 0.05050357 0.31461016 0.27836512]
#  [0.6124151  0.70910652 0.52972324 0.05519194 0.77163966 0.02854779
#   0.28004997 0.59104158 0.53484814 0.66961586]
#  [0.60577345 0.37855278 0.17501792 0.33399598 0.51029578 0.07497713
#   0.95374499 0.37582343 0.03524439 0.86570396]
#  [0.02988814 0.88110513 0.00644258 0.42558355 0.40626882 0.95288279
#   0.97238817 0.62480391 0.57927063 0.01584967]
#  [0.52885378 0.56913892 0.43192848 0.21574695 0.96660761 0.1680247
#   0.59951892 0.80026844 0.12579844 0.43353618]]
# W2
# [[0.79168982 0.23908796 0.03729415 0.56351021 0.40274911 0.42455953
#   0.07674148 0.5118248  0.91432229 0.97438715 0.83036536 0.35568849
#   0.54590009 0.08608271 0.73100749]
#  [0.99459597 0.64321045 0.55406412 0.19073146 0.80531612 0.12612199
#   0.81220843 0.14741887 0.80602923 0.34589019 0.00284362 0.9815386
#   0.53709481 0.95404421 0.14886474]
# ...

# %%
nn.printForArduino() # formato C para código Arduino.
# Out:
# //Weights:
#
# ...
